# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
df = pd.read_csv('dataset.csv')
# Drop columns with NaN entries
df = df.dropna(1)
df.head(10)
# Out:
#       angle  curLapTime  damage  distFromStart  distRaced  fuel  gear  \
# 0  0.009693       0.782     0.0        2032.56   0.000000  94.0   0.0
# 1  0.009693       0.562     0.0        2032.56   0.000000  94.0   0.0
# 2  0.009693       0.342     0.0        2032.56   0.000000  94.0   0.0
# 3  0.009693       0.122     0.0        2032.56   0.000000  94.0   0.0
# 4  0.010925       0.118     0.0        2032.56   0.000000  94.0   1.0
# 5  0.012997       0.340     0.0        2032.56   0.000122  94.0   1.0
# 6  0.014956       0.562     0.0        2032.56   0.000244  94.0   1.0
# 7  0.017058       0.782     0.0        2032.56   0.000366  94.0   1.0
# 8  0.018819       1.004     0.0        2032.56   0.000488  94.0   1.0
# 9  0.020567       1.224     0.0        2032.56   0.000610  94.0   1.0
#
#    lastLapTime  opponents  opponents.1  ...  focus.2  focus.3  focus.4  accel  \
# 0          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 1          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 2          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 3          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 4          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 5          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 6          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 7          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 8          0.0        200          200  ...      1.0      1.0      1.0    0.0
# 9          0.0        200          200  ...      1.0      1.0      1.0    1.0
#
#    brake  gear.1     steer    clutch  focus.5  meta
# 0    1.0       1  0.200077  0.000000      0.0     0
# 1    1.0       1  0.200077  0.000000      0.0     0
# 2    1.0       1  0.200077  0.000000      0.0     0
# 3    1.0       1  0.200077  0.000000      0.0     0
# 4    1.0       1  0.198523  0.000000      0.0     0
# 5    1.0       1  0.195909  0.000000      0.0     0
# 6    1.0       1  0.193441  0.000000      0.0     0
# 7    1.0       1  0.190789  0.000000      0.0     0
# 8    1.0       1  0.188571  0.000000      0.0     0
# 9    0.0       1  1.000000  0.186372      0.0     0
#
# [10 rows x 86 columns]

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()
targets = ['gear.1', 'steer', 'clutch'	]
features = [col for col in df.columns]
for i in range(10):
    features.pop()

features.append('focus.5')
X = df[features]

# %%
for i in range(len(targets)):
    Y = df[targets[i]]
    print("Current Attribute: ", targets[i])
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1) # 80% training and 20% test


    # Train Decision Tree Classifer
    clf = clf.fit(X_train,y_train)

    #Predict the response for test dataset
    y_pred = clf.predict(X_test)
    print("Accuracy: ",metrics.accuracy_score(y_test, y_pred), "of attribute: ", targets[i])
# Out:
# Current Attribute:  gear.1
# Accuracy:  1.0 of attribute:  gear.1
# Current Attribute:  steer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-fbde58ea7181> in <module>
#       6
#       7     # Train Decision Tree Classifer
# ----> 8     clf = clf.fit(X_train,y_train)
#       9
#      10     #Predict the response for test dataset
#
# c:\Users\danya\anaconda3\envs\DIP\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     896         """
#     897
# --> 898         super().fit(
#     899             X, y,
#     900             sample_weight=sample_weight,
#
# c:\Users\danya\anaconda3\envs\DIP\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     188
#     189         if is_classification:
# --> 190             check_classification_targets(y)
#     191             y = np.copy(y)
#     192
#
# c:\Users\danya\anaconda3\envs\DIP\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'

# %%
# Out:
# Accuracy: 0.9758454106280193
