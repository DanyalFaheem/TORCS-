# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
df = pd.read_csv(r"C:\Danyal\Work\FAST\Semester 6\Artificial Intelligence\Project\i192194_i192199_i2192014_F.csv", nrows=300)
# Drop columns with NaN entries
df = df.dropna(1)
df.head(10)
# Out:
#       angle  curLapTime  damage  distFromStart  distRaced     fuel  gear  \
# 0  0.009693       0.782       0        2032.56   0.000000  94.0000     0
# 1  0.009693       0.562       0        2032.56   0.000000  94.0000     0
# 2  0.009693       0.342       0        2032.56   0.000000  93.9995     0
# 3  0.009693       0.122       0        2032.56   0.000000  93.9965     0
# 4  0.009068       0.118       0        2032.56   0.000854  93.9910     1
# 5  0.009666       0.340       0        2032.63   0.065674  93.9910     1
# 6  0.013957       0.562       0        2032.92   0.362549  93.9910     1
# 7  0.007313       0.782       0        2033.45   0.892090  93.9905     1
# 8  0.006170       1.004       0        2034.24   1.676510  93.9897     1
# 9  0.027951       1.224       0        2035.27   2.712400  93.9888     1
#
#    lastLapTime  opponents  opponents.1  ...  focus.2  focus.3  focus.4  accel  \
# 0            0    19.2186        200.0  ...      1.0      1.0      1.0    0.0
# ...

# %%
targets = ['gear.1', 'steer', 'clutch', 'brake']
for target in targets:
    print(target, df[target].unique())
# Out:
# gear.1 [1 0 2 3 4 5 6]
# steer [0.       0.785398 1.      ]
# clutch [0]
# brake [0.  1.  1.1]

# %%
# Create Decision Tree classifer object
clfd = DecisionTreeClassifier()
targets = ['gear.1', 'steer', 'clutch', 'brake']
features = [col for col in df.columns]
for i in range(7):
    features.pop()

features.append('focus.5')
X = df[features]

# %%
# for i in range(len(targets)):
#     Y = df[targets[i]]
#     print("Current Attribute: ", targets[i])
#     X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1) # 80% training and 20% test


#     # Train Decision Tree Classifer
#     clfd = clfd.fit(X_train,y_train)

#     #Predict the response for test dataset
#     y_pred = clfd.predict(X_test)
#     print("Accuracy: ",metrics.accuracy_score(y_test, y_pred), "of attribute: ", targets[i])

# %%
for i in range(len(targets)):
    rgr = DecisionTreeRegressor()
    Y = df[targets[i]]
    print("Current Attribute: ", targets[i])
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2) # 80% training and 20% test


    # Train Decision Tree Classifer
    rgr = rgr.fit(X_train,y_train)

    #Predict the response for test dataset
    y_pred = rgr.predict(X_test.iloc[0])
    # print("Accuracy: ",rgr.score(X_test, y_test))
    # print("Accuracy: ",metrics.accuracy_score(y_test, y_pred), "of attribute: ", targets[i])
# print(X_test, y_pred)
# Out:
# Current Attribute:  gear.1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d3826a5b7e71> in <module>
#      10
#      11     #Predict the response for test dataset
# ---> 12     y_pred = rgr.predict(X_test.iloc[0])
#      13     # print("Accuracy: ",rgr.score(X_test, y_test))
#      14     print("Accuracy: ",metrics.accuracy_score(y_test, y_pred), "of attribute: ", targets[i])
#
# c:\Users\danya\anaconda3\envs\DIP\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     435         """
#     436         check_is_fitted(self)
# --> 437         X = self._validate_X_predict(X, check_input)
#     438         proba = self.tree_.predict(X)
#     439         n_samples = X.shape[0]
#
# c:\Users\danya\anaconda3\envs\DIP\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
# ...

# %%
# for i in range(len(targets)):
#     clfr = RandomForestRegressor()
#     Y = df[targets[i]]
#     print("Current Attribute: ", targets[i])
#     X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2) # 80% training and 20% test


#     # Train Decision Tree Classifer
#     clfr = clfr.fit(X_train,y_train)

#     #Predict the response for test dataset
#     y_pred = clfr.predict(X_test)
#     # print(y_test, y_pred)
#     print("Accuracy: ",rgr.score(X_test, y_test))

# # print("Accuracy: ",metrics.accuracy_score(y_test, y_pred), "of attribute: ", targets[i])
